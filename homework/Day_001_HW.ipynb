# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：https://www.kaggle.com/vjchoudhary7/customer-segmentation-tutorial-in-python
#
# 1. 你選的這組資料為何重要 符合目前工作預定的學習目標
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)   Udemy's Machine Learning A-Z course 所提供的 Mall Customer data
#
# 3. 蒐集而來的資料型態為何 CSV files
#
# 4. 這組資料想解決的問題如何評估 是否可以使用提供的資料完成準確的市場分隔 並對於各個市場能提供相應的策略
#
#
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 進入自由載客市場"初期"將著重於提升市場的知名度及維持服務水準(便利性,準時,安全性,舒適度...) 可以投資數位廣告以善用APP及社群網路建立穩定客群成長,除散客外並尋求與其他上游企業合作,避免削價競爭,建立公司良好的品牌形象,追蹤客戶滿意度,強化客服團隊
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# APP下載率,載客率,返客率,新客率,市占率,問卷,平均載客/平均里程/平均旅程時間,數位廣告點擊率 可經由媒體公司,市調公司,及公司內部CRM系統取得
#
#
# 3. 蒐集而來的資料型態為何
# 結構化資料為主 問券及社群為輔
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證) 廣告投入,廣告點擊率,載客率成長率,客戶滿意度,業績成長率 彼此間的關係, 假設廣告投入會增加公司業績(APP下載增加,載客量增加),提升顧客滿意度可以建立忠誠客群並吸引新客群
#
#
# 作業3：
#
# 請點選下方檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
#
# 資料夾結構建立規則提醒：2nd-ML100Days > data資料夾 & homework資料夾 (ipynb檔)
#
# (請注意data的存放位置，建議放在*.ipynb 同一個目錄下，這樣才能在不修改code的情況下正常執行)

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yp):
    mse = sum((y - yp)**2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 231.514
# The Mean absolute error is 11.779
